# %%
# %load_ext autoreload
# %autoreload 2
# Do not run this cell unless running the code on a local notebook. This line is for auto-reloading the code in the notebook whenever you make changes to the code files. 
# If you're running this code in a Jupyter notebook/ Google Colab, you can uncomment the line to enable auto-reloading of your code files.

# %%
# %pip install  torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Use it only if you are sure GPU is available and compatible with CUDA 12.1+. Otherwise, you can install the CPU version or the appropriate CUDA version for your system.

# %%
# -----------------------------
# Environment configuration
# -----------------------------
gpu_available = True   # <-- change to True to enable GPU scheduling

# What to do with GPU tasks when gpu_available=False:
DOWNGRADE_GPU_TASKS_TO_CPU = True   # True = run them on CPU, False = reject them

# For clearer scheduling behavior in demos, cap CPU cores (optional)
CPU_CORES_CAP: int = 8                      # set None or large number to remove cap

# Run settings
DEFAULT_RUN_SECONDS: float = 3.0
SENSOR_PERIOD_S: float = 0.12               # sensor event rate (larger => fewer logs)
HEALTH_PERIOD_S: float = 1.0                # health monitor interval

# %%
# ============================
# Task 3: Defense AI System Simulation (CPU-only + logical GPUs)
# Multi-agent + Orchestrated pipelines + Priority scheduling + Fault tolerance
# ============================

import asyncio
import heapq
import os
import random
import sys
import time
from dataclasses import dataclass, field
from datetime import datetime
from typing import Any, Callable, Dict, List, Optional

# %%
# -------------------------------------------------------------------
# Logging to read later (writes to file AND notebook output)
# -------------------------------------------------------------------
class Tee:
    def __init__(self, *streams):
        self.streams = streams
    def write(self, data):
        for s in self.streams:
            s.write(data)
            s.flush()
    def flush(self):
        for s in self.streams:
            s.flush()

class LogContext:
    def __init__(self, log_file: str, fh, orig_out, orig_err):
        self.log_file = log_file
        self._fh = fh
        self._orig_out = orig_out
        self._orig_err = orig_err
    def close(self):
        # restore stdio
        sys.stdout = self._orig_out
        sys.stderr = self._orig_err
        try:
            self._fh.flush()
        finally:
            self._fh.close()

def log_writer() -> LogContext:
    log_dir = "logs"
    os.makedirs(log_dir, exist_ok=True)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = os.path.join(log_dir, f"task3_{ts}.log")

    if os.path.exists(log_file):
        os.remove(log_file)

    log_fh = open(log_file, "w", encoding="utf-8")

    # Keep originals so Jupyter still displays output
    original_stdout = sys.stdout
    original_stderr = sys.stderr

    sys.stdout = Tee(original_stdout, log_fh)
    sys.stderr = Tee(original_stderr, log_fh)

    print("=== Logging Enabled ===")
    print("Log file:", log_file)
    print("=======================\n")

    return LogContext(log_file, log_fh, original_stdout, original_stderr)

def log(msg: str):
    # Single place to emit output so it always hits both notebook and file (via Tee)
    print(msg)

# %%
# -------------------------------------------------------------------
# 2) LOGICAL RESOURCES
# -------------------------------------------------------------------
@dataclass
class LogicalCluster:
    cpu_cores: int
    gpus: int
    cpu_sem: asyncio.Semaphore = field(init=False)
    gpu_sem: asyncio.Semaphore = field(init=False)

    def __post_init__(self):
        self.cpu_sem = asyncio.Semaphore(self.cpu_cores)
        self.gpu_sem = asyncio.Semaphore(self.gpus)

async def acquire_n(sem: asyncio.Semaphore, n: int):
    for _ in range(max(0, n)):
        await sem.acquire()

def release_n(sem: asyncio.Semaphore, n: int):
    for _ in range(max(0, n)):
        sem.release()

# %%
# -------------------------------------------------------------------
# 3) EVENTS + BUS (Resource Allocation and Shutdown Function)
# -------------------------------------------------------------------
@dataclass
class SensorEvent:
    source: str
    ts: float
    data: Dict[str, Any]

STOP_EVENT = SensorEvent(source="__STOP__", ts=0.0, data={"stop": True})

class EventBus:
    def __init__(self):
        self.q: asyncio.Queue[SensorEvent] = asyncio.Queue()

    async def publish(self, ev: SensorEvent):
        await self.q.put(ev)

    async def subscribe(self) -> SensorEvent:
        ev = await self.q.get()
        # important: prevents join-style hangs if you ever add them later
        self.q.task_done()
        return ev

# %%
# -------------------------------------------------------------------
# 4) TASK + DLQ (Task Handler and Dead Letter Queue)
# -------------------------------------------------------------------
@dataclass(order=True)
class ScheduledItem:
    priority: int
    created_at: float
    seq: int
    task: "Task" = field(compare=False)

@dataclass
class Task:
    task_id: str
    agent: str
    kind: str
    cpu_cores: int
    gpus: int
    est_s: float
    priority: int                   # lower = higher priority
    payload: Dict[str, Any] = field(default_factory=dict)

    max_retries: int = 2
    retry_backoff_s: float = 0.3
    fail_prob: float = 0.05
    submitted_at: float = field(default_factory=time.time)
    attempt: int = 0

@dataclass
class DeadLetter:
    task: Task
    error: str
    when: float = field(default_factory=time.time)

# %%
# -------------------------------------------------------------------
# 5) MULTI-AGENT SIMULATIONS ALLOCATION
# -------------------------------------------------------------------
def ingest_agent(task: Task):
    task.payload["ingested"] = True

def preprocess_agent(task: Task):
    task.payload["preprocessed"] = True

def fusion_agent(task: Task):
    task.payload["fused"] = True

def threat_detect_agent(task: Task):
    base = task.payload.get("signal_strength", 0.5)
    if task.payload.get("degraded"):
        base *= 0.9
    task.payload["threat_score"] = min(1.0, max(0.0, base + random.uniform(-0.1, 0.2)))

def decision_agent(task: Task):
    score = task.payload.get("threat_score", 0.0)
    task.payload["decision"] = "INTERCEPT" if score >= 0.75 else ("MONITOR" if score >= 0.5 else "IGNORE")

def comms_agent(task: Task):
    # In real systems: publish to C2, alerts, logs
    pass

def batch_analytics_agent(task: Task):
    task.payload["batch_report"] = "ok"

def model_update_agent(task: Task):
    task.payload["model_update"] = "staged"

AGENTS: Dict[str, Callable[[Task], Any]] = {
    "ingest": ingest_agent,
    "preprocess": preprocess_agent,
    "fusion": fusion_agent,
    "threat": threat_detect_agent,
    "decision": decision_agent,
    "comms": comms_agent,
    "batch": batch_analytics_agent,
    "model_update": model_update_agent,
}

# %%
# -------------------------------------------------------------------
# 6) PRIORITY SCHEDULER FOR RT(Real Time) + BATCH TASKS
# -------------------------------------------------------------------
class PriorityScheduler:
    def __init__(self, cluster: LogicalCluster):
        self.cluster = cluster
        self._rt_heap: List[ScheduledItem] = []
        self._batch_heap: List[ScheduledItem] = []
        self._seq = 0
        self.running: List[asyncio.Task] = []
        self.dead_letter: List[DeadLetter] = []
        self.stats = {
            "submitted": 0,
            "started": 0,
            "succeeded": 0,
            "failed": 0,
            "retried": 0,
            "dlq": 0,
        }

    def submit(self, task: Task):
        # Apply GPU availability policy
        if not gpu_available and task.gpus > 0:
            if DOWNGRADE_GPU_TASKS_TO_CPU:
                task.gpus = 0
                task.payload["degraded"] = True
            else:
                self.dead_letter.append(DeadLetter(task, "GPU not available (policy reject)"))
                self.stats["dlq"] += 1
                return

        self._seq += 1
        item = ScheduledItem(task.priority, time.time(), self._seq, task)
        if task.priority <= 4:
            heapq.heappush(self._rt_heap, item)
        else:
            heapq.heappush(self._batch_heap, item)
        self.stats["submitted"] += 1

    def _pick_next(self) -> Optional[Task]:
        if self._rt_heap:
            return heapq.heappop(self._rt_heap).task
        if self._batch_heap:
            return heapq.heappop(self._batch_heap).task
        return None

    def _cleanup_running(self):
        self.running = [t for t in self.running if not t.done()]

    async def _execute(self, task: Task, t0: float, stop_event: asyncio.Event):
        # Admission control
        if task.cpu_cores > self.cluster.cpu_cores or task.gpus > self.cluster.gpus:
            self.dead_letter.append(DeadLetter(task, "request exceeds cluster capacity"))
            self.stats["dlq"] += 1
            return

        # Acquire resources
        await acquire_n(self.cluster.cpu_sem, task.cpu_cores)
        if task.gpus > 0:
            await acquire_n(self.cluster.gpu_sem, task.gpus)

        place = "GPU" if task.gpus > 0 else "CPU"
        wait_s = time.time() - task.submitted_at
        degraded = " degraded" if task.payload.get("degraded") else ""

        need_retry = False
        retry_delay = 0.0
        err: Optional[str] = None

        try:
            self.stats["started"] += 1
            log(f"[{time.time()-t0:6.2f}s] START {task.task_id:16} "
                f"agent={task.agent:11} kind={task.kind:12} on={place}{degraded} "
                f"wait={wait_s:5.2f}s req(cpu={task.cpu_cores}, gpu={task.gpus}) attempt={task.attempt}")

            await asyncio.sleep(task.est_s)

            if random.random() < task.fail_prob:
                raise RuntimeError("simulated transient failure")

            fn = AGENTS.get(task.agent, lambda _t: None)
            fn(task)

            self.stats["succeeded"] += 1
            log(f"[{time.time()-t0:6.2f}s] DONE  {task.task_id:16} agent={task.agent:11} on={place}")

        except Exception as e:
            self.stats["failed"] += 1
            err = f"{type(e).__name__}: {e}"
            log(f"[{time.time()-t0:6.2f}s] FAIL  {task.task_id:16} agent={task.agent:11} err={err}")

            # Decide retry *now*, but perform the sleep/submission only AFTER releasing resources.
            if (task.attempt < task.max_retries) and (not stop_event.is_set()):
                task.attempt += 1
                self.stats["retried"] += 1
                need_retry = True
                retry_delay = task.retry_backoff_s * task.attempt
            else:
                self.dead_letter.append(DeadLetter(task, err))
                self.stats["dlq"] += 1

        finally:
            # Always release resources immediately
            if task.gpus > 0:
                release_n(self.cluster.gpu_sem, task.gpus)
            release_n(self.cluster.cpu_sem, task.cpu_cores)

        # Retry happens here (resources already released)
        if need_retry and (not stop_event.is_set()):
            await asyncio.sleep(retry_delay)
            # re-submit with updated submitted_at so wait times make sense
            task.submitted_at = time.time()
            self.submit(task)

    async def run_loop(self, t0: float, stop_event: asyncio.Event):
        while not stop_event.is_set():
            self._cleanup_running()
            task = self._pick_next()
            if task is None:
                await asyncio.sleep(0.02)
                continue
            self.running.append(asyncio.create_task(self._execute(task, t0, stop_event)))

        # On stop: cancel outstanding *queued* work by clearing heaps
        self._rt_heap.clear()
        self._batch_heap.clear()

        # Drain running tasks, but don't hang forever
        deadline = time.time() + 2.0
        while self.running and time.time() < deadline:
            self._cleanup_running()
            await asyncio.sleep(0.05)

        # If anything still running, cancel it
        for t in self.running:
            if not t.done():
                t.cancel()
        await asyncio.gather(*self.running, return_exceptions=True)
        self.running.clear()

# %%
# -------------------------------------------------------------------
# 7) PIPELINE ORCHESTRATOR (RT + batch)
# -------------------------------------------------------------------
class PipelineOrchestrator:
    def __init__(self, scheduler: PriorityScheduler, bus: EventBus):
        self.scheduler = scheduler
        self.bus = bus
        self.counter = 0

    def _id(self, prefix: str) -> str:
        self.counter += 1
        return f"{prefix}_{self.counter:04d}"

    def submit_realtime_pipeline(self, ev: SensorEvent):
        mission_id = self._id("RT")
        payload = {
            "mission_id": mission_id,
            "source": ev.source,
            "signal_strength": ev.data.get("signal_strength", 0.5),
            "ts": ev.ts,
        }

        tasks = [
            Task(f"{mission_id}_ingest",   "ingest",     "ingest",       1, 0, 0.10, 0, payload, fail_prob=0.02),
            Task(f"{mission_id}_pre",      "preprocess", "preprocess",   1, 0, 0.12, 0, payload, fail_prob=0.03),
            Task(f"{mission_id}_fusion",   "fusion",     "fusion",       1, 0, 0.15, 0, payload, fail_prob=0.03),
            Task(f"{mission_id}_threat",   "threat",     "threat_detect",2, 1, 0.25, 0, payload, fail_prob=0.06),
            Task(f"{mission_id}_decision", "decision",   "decision",     1, 0, 0.08, 0, payload, fail_prob=0.02),
            Task(f"{mission_id}_comms",    "comms",      "comms",        1, 0, 0.06, 0, payload, fail_prob=0.01),
        ]
        for t in tasks:
            self.scheduler.submit(t)

    def submit_batch_pipeline(self):
        batch_id = self._id("BATCH")
        payload = {"batch_id": batch_id, "ts": time.time()}

        tasks = [
            Task(f"{batch_id}_analytics", "batch",       "batch_analytics", 4, 0, 1.20, 10, payload, fail_prob=0.08),
            Task(f"{batch_id}_model_upd", "model_update","model_update",    2, 1, 1.00, 10, payload, fail_prob=0.10),
        ]
        for t in tasks:
            self.scheduler.submit(t)

    async def event_listener(self, stop_event: asyncio.Event):
        # Clean shutdown: listener exits when it receives STOP_EVENT
        while True:
            ev = await self.bus.subscribe()
            if ev.data.get("stop"):
                break
            self.submit_realtime_pipeline(ev)

# %%
# -------------------------------------------------------------------
# 8) MONITORS + SIMULATORS
# -------------------------------------------------------------------
async def health_monitor(scheduler: PriorityScheduler, t0: float, stop_event: asyncio.Event):
    while not stop_event.is_set():
        await asyncio.sleep(HEALTH_PERIOD_S)
        s = scheduler.stats
        log(f"[{time.time()-t0:6.2f}s] HEALTH sub={s['submitted']} start={s['started']} "
            f"ok={s['succeeded']} fail={s['failed']} retry={s['retried']} dlq={s['dlq']} "
            f"dlq_items={len(scheduler.dead_letter)}")

async def sensor_simulator(bus: EventBus, stop_event: asyncio.Event):
    sources = ["radar", "eo_ir", "telemetry"]
    while not stop_event.is_set():
        src = random.choice(sources)
        ev = SensorEvent(source=src, ts=time.time(), data={"signal_strength": random.random()})
        await bus.publish(ev)
        await asyncio.sleep(SENSOR_PERIOD_S)

async def batch_submitter(orch: PipelineOrchestrator, stop_event: asyncio.Event):
    while not stop_event.is_set():
        await asyncio.sleep(2.0)
        orch.submit_batch_pipeline()

# %%
# -------------------------------------------------------------------
# 9) MAIN ENTRY POINT
# -------------------------------------------------------------------
async def run_sim(run_seconds: float = DEFAULT_RUN_SECONDS,
                  enable_logging: bool = True) -> Dict[str, Any]:
    """
    Run the simulation for run_seconds and return summary dict.
    Enforces a hard time bound: will stop & shut down within run_seconds (+ small grace).
    """
    log_ctx = log_writer() if enable_logging else None

    t0 = time.time()
    random.seed(7)

    cpu_cores = os.cpu_count() or 1
    if CPU_CORES_CAP is not None:
        cpu_cores = min(cpu_cores, CPU_CORES_CAP)

    gpus_used = 1 if gpu_available else 0

    log("=== On-Prem Logical Deployment ===")
    log(f"CPU logical cores (used): {cpu_cores}")
    log(f"gpu_available flag: {gpu_available}")
    log(f"DOWNGRADE_GPU_TASKS_TO_CPU: {DOWNGRADE_GPU_TASKS_TO_CPU}")
    log(f"Logical GPU tokens: {gpus_used}")
    if log_ctx:
        log(f"Log file: {log_ctx.log_file}")
    log("")

    cluster = LogicalCluster(cpu_cores=cpu_cores, gpus=gpus_used)
    scheduler = PriorityScheduler(cluster)
    bus = EventBus()
    orch = PipelineOrchestrator(scheduler, bus)
    stop_event = asyncio.Event()

    bg_tasks = [
        asyncio.create_task(sensor_simulator(bus, stop_event)),
        asyncio.create_task(orch.event_listener(stop_event)),
        asyncio.create_task(scheduler.run_loop(t0, stop_event)),
        asyncio.create_task(health_monitor(scheduler, t0, stop_event)),
        asyncio.create_task(batch_submitter(orch, stop_event)),
    ]

    async def _run_window():
        await asyncio.sleep(run_seconds)

    # Hard time bound + small grace for shutdown
    try:
        await asyncio.wait_for(_run_window(), timeout=run_seconds + 0.1)
    finally:
        stop_event.set()
        # Wake event listener so it can exit immediately
        await bus.publish(STOP_EVENT)

        # Give background tasks a small grace period to exit cleanly
        try:
            await asyncio.wait_for(asyncio.gather(*bg_tasks, return_exceptions=True), timeout=2.5)
        except asyncio.TimeoutError:
            # Cancel anything still alive
            for t in bg_tasks:
                if not t.done():
                    t.cancel()
            await asyncio.gather(*bg_tasks, return_exceptions=True)

    log("\n=== FINAL STATS ===")
    log(str(scheduler.stats))
    log(f"DLQ items: {len(scheduler.dead_letter)}")
    if scheduler.dead_letter:
        dlq0 = scheduler.dead_letter[0]
        log(f"Sample DLQ: {dlq0.task.task_id} | {dlq0.error}")
    if log_ctx:
        log(f"\nLog saved to: {log_ctx.log_file}")
        # restore stdout/stderr at the end
        log_ctx.close()

    return {
        "stats": scheduler.stats,
        "dlq_count": len(scheduler.dead_letter),
        "log_file": (log_ctx.log_file if log_ctx else None),
    }

# %%
# -------------------------------------------------------------------
# 10) Run Script
# -------------------------------------------------------------------
def run_sim_script():
    asyncio.run(run_sim(DEFAULT_RUN_SECONDS, enable_logging=True))
await run_sim(30, enable_logging=True)
# Out:
# === Logging Enabled ===
# Log file: logs/task3_20260204_230517.log
# =======================
#
# === On-Prem Logical Deployment ===
# CPU logical cores (used): 8
# gpu_available flag: True
# DOWNGRADE_GPU_TASKS_TO_CPU: True
# Logical GPU tokens: 1
# Log file: logs/task3_20260204_230517.log
#
# [  0.01s] START RT_0001_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.00s req(cpu=1, gpu=0) attempt=0
# [  0.01s] START RT_0001_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.00s req(cpu=1, gpu=0) attempt=0
# [  0.01s] START RT_0001_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.00s req(cpu=1, gpu=0) attempt=0
# [  0.01s] START RT_0001_threat   agent=threat      kind=threat_detect on=GPU wait= 0.00s req(cpu=2, gpu=1) attempt=0
# [  0.01s] START RT_0001_decision agent=decision    kind=decision     on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.02s] START RT_0001_comms    agent=comms       kind=comms        on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.08s] DONE  RT_0001_comms    agent=comms       on=CPU
# [  0.10s] DONE  RT_0001_decision agent=decision    on=CPU
# [  0.11s] DONE  RT_0001_ingest   agent=ingest      on=CPU
# [  0.13s] DONE  RT_0001_pre      agent=preprocess  on=CPU
# [  0.14s] START RT_0002_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.14s] START RT_0002_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.14s] START RT_0002_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.16s] DONE  RT_0001_fusion   agent=fusion      on=CPU
# [  0.16s] START RT_0002_decision agent=decision    kind=decision     on=CPU wait= 0.03s req(cpu=1, gpu=0) attempt=0
# [  0.24s] DONE  RT_0002_ingest   agent=ingest      on=CPU
# [  0.24s] START RT_0002_comms    agent=comms       kind=comms        on=CPU wait= 0.11s req(cpu=1, gpu=0) attempt=0
# [  0.25s] DONE  RT_0002_decision agent=decision    on=CPU
# [  0.26s] DONE  RT_0002_pre      agent=preprocess  on=CPU
# [  0.26s] START RT_0003_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.26s] START RT_0003_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.01s req(cpu=1, gpu=0) attempt=0
# [  0.27s] FAIL  RT_0001_threat   agent=threat      err=RuntimeError: simulated transient failure
# [  0.27s] START RT_0002_threat   agent=threat      kind=threat_detect on=GPU wait= 0.14s req(cpu=2, gpu=1) attempt=0
# [  0.27s] START RT_0003_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.02s req(cpu=1, gpu=0) attempt=0
# [  0.29s] DONE  RT_0002_fusion   agent=fusion      on=CPU
# [  0.29s] START RT_0003_decision agent=decision    kind=decision     on=CPU wait= 0.04s req(cpu=1, gpu=0) attempt=0
# [  0.30s] DONE  RT_0002_comms    agent=comms       on=CPU
# [  0.31s] START RT_0003_comms    agent=comms       kind=comms        on=CPU wait= 0.05s req(cpu=1, gpu=0) attempt=0
# [  0.36s] DONE  RT_0003_ingest   agent=ingest      on=CPU
# [  0.37s] DONE  RT_0003_comms    agent=comms       on=CPU
# [  0.37s] DONE  RT_0003_decision agent=decision    on=CPU
# [  0.39s] DONE  RT_0003_pre      agent=preprocess  on=CPU
# [  0.39s] START RT_0004_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.02s req(cpu=1, gpu=0) attempt=0
# [  0.39s] START RT_0004_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.02s req(cpu=1, gpu=0) attempt=0
# [  0.39s] START RT_0004_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.02s req(cpu=1, gpu=0) attempt=0
# [  0.42s] DONE  RT_0003_fusion   agent=fusion      on=CPU
# [  0.49s] DONE  RT_0004_ingest   agent=ingest      on=CPU
# [  0.49s] START RT_0004_decision agent=decision    kind=decision     on=CPU wait= 0.12s req(cpu=1, gpu=0) attempt=0
# [  0.51s] DONE  RT_0004_pre      agent=preprocess  on=CPU
# [  0.51s] START RT_0004_comms    agent=comms       kind=comms        on=CPU wait= 0.14s req(cpu=1, gpu=0) attempt=0
# [  0.52s] DONE  RT_0002_threat   agent=threat      on=GPU
# [  0.52s] START RT_0003_threat   agent=threat      kind=threat_detect on=GPU wait= 0.27s req(cpu=2, gpu=1) attempt=0
# [  0.52s] START RT_0005_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.03s req(cpu=1, gpu=0) attempt=0
# [  0.54s] DONE  RT_0004_fusion   agent=fusion      on=CPU
# [  0.55s] START RT_0005_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.05s req(cpu=1, gpu=0) attempt=0
# [  0.58s] DONE  RT_0004_decision agent=decision    on=CPU
# [  0.58s] DONE  RT_0004_comms    agent=comms       on=CPU
# [  0.58s] START RT_0005_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.08s req(cpu=1, gpu=0) attempt=0
# [  0.62s] DONE  RT_0005_ingest   agent=ingest      on=CPU
# [  0.62s] START RT_0005_decision agent=decision    kind=decision     on=CPU wait= 0.13s req(cpu=1, gpu=0) attempt=0
# [  0.67s] DONE  RT_0005_pre      agent=preprocess  on=CPU
# [  0.67s] START RT_0005_comms    agent=comms       kind=comms        on=CPU wait= 0.17s req(cpu=1, gpu=0) attempt=0
# [  0.71s] DONE  RT_0005_decision agent=decision    on=CPU
# [  0.73s] DONE  RT_0005_fusion   agent=fusion      on=CPU
# [  0.73s] DONE  RT_0005_comms    agent=comms       on=CPU
# [  0.73s] START RT_0006_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.12s req(cpu=1, gpu=0) attempt=0
# [  0.77s] DONE  RT_0003_threat   agent=threat      on=GPU
# [  0.77s] START RT_0004_threat   agent=threat      kind=threat_detect on=GPU wait= 0.40s req(cpu=2, gpu=1) attempt=0
# [  0.78s] START RT_0006_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.16s req(cpu=1, gpu=0) attempt=0
# [  0.78s] START RT_0006_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.16s req(cpu=1, gpu=0) attempt=0
# [  0.84s] DONE  RT_0006_ingest   agent=ingest      on=CPU
# [  0.90s] DONE  RT_0006_pre      agent=preprocess  on=CPU
# [  0.90s] START RT_0006_decision agent=decision    kind=decision     on=CPU wait= 0.28s req(cpu=1, gpu=0) attempt=0
# [  0.93s] DONE  RT_0006_fusion   agent=fusion      on=CPU
# [  0.93s] START RT_0006_comms    agent=comms       kind=comms        on=CPU wait= 0.31s req(cpu=1, gpu=0) attempt=0
# [  0.98s] DONE  RT_0006_decision agent=decision    on=CPU
# [  0.99s] DONE  RT_0006_comms    agent=comms       on=CPU
# [  0.99s] START RT_0007_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.25s req(cpu=1, gpu=0) attempt=0
# [  1.01s] HEALTH sub=55 start=35 ok=32 fail=1 retry=1 dlq=0 dlq_items=0
# [  1.03s] DONE  RT_0004_threat   agent=threat      on=GPU
# [  1.03s] START RT_0005_threat   agent=threat      kind=threat_detect on=GPU wait= 0.53s req(cpu=2, gpu=1) attempt=0
# [  1.03s] START RT_0007_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.29s req(cpu=1, gpu=0) attempt=0
# [  1.03s] START RT_0007_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.29s req(cpu=1, gpu=0) attempt=0
# [  1.09s] DONE  RT_0007_ingest   agent=ingest      on=CPU
# [  1.15s] DONE  RT_0007_pre      agent=preprocess  on=CPU
# [  1.15s] START RT_0007_decision agent=decision    kind=decision     on=CPU wait= 0.42s req(cpu=1, gpu=0) attempt=0
# [  1.18s] DONE  RT_0007_fusion   agent=fusion      on=CPU
# [  1.18s] START RT_0007_comms    agent=comms       kind=comms        on=CPU wait= 0.45s req(cpu=1, gpu=0) attempt=0
# [  1.24s] DONE  RT_0007_decision agent=decision    on=CPU
# [  1.25s] DONE  RT_0007_comms    agent=comms       on=CPU
# [  1.25s] START RT_0008_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.39s req(cpu=1, gpu=0) attempt=0
# [  1.28s] DONE  RT_0005_threat   agent=threat      on=GPU
# [  1.28s] START RT_0001_threat   agent=threat      kind=threat_detect on=GPU wait= 0.71s req(cpu=2, gpu=1) attempt=1
# [  1.28s] START RT_0008_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.42s req(cpu=1, gpu=0) attempt=0
# [  1.29s] START RT_0008_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.43s req(cpu=1, gpu=0) attempt=0
# [  1.35s] DONE  RT_0008_ingest   agent=ingest      on=CPU
# [  1.41s] DONE  RT_0008_pre      agent=preprocess  on=CPU
# [  1.41s] START RT_0008_decision agent=decision    kind=decision     on=CPU wait= 0.55s req(cpu=1, gpu=0) attempt=0
# [  1.44s] DONE  RT_0008_fusion   agent=fusion      on=CPU
# [  1.44s] START RT_0008_comms    agent=comms       kind=comms        on=CPU wait= 0.58s req(cpu=1, gpu=0) attempt=0
# [  1.49s] DONE  RT_0008_decision agent=decision    on=CPU
# [  1.49s] START RT_0009_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.51s req(cpu=1, gpu=0) attempt=0
# [  1.50s] DONE  RT_0008_comms    agent=comms       on=CPU
# [  1.50s] START RT_0009_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.52s req(cpu=1, gpu=0) attempt=0
# [  1.54s] DONE  RT_0001_threat   agent=threat      on=GPU
# [  1.54s] START RT_0006_threat   agent=threat      kind=threat_detect on=GPU wait= 0.92s req(cpu=2, gpu=1) attempt=0
# [  1.54s] START RT_0009_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.55s req(cpu=1, gpu=0) attempt=0
# [  1.59s] DONE  RT_0009_ingest   agent=ingest      on=CPU
# [  1.59s] START RT_0009_decision agent=decision    kind=decision     on=CPU wait= 0.61s req(cpu=1, gpu=0) attempt=0
# [  1.62s] DONE  RT_0009_pre      agent=preprocess  on=CPU
# [  1.63s] START RT_0009_comms    agent=comms       kind=comms        on=CPU wait= 0.64s req(cpu=1, gpu=0) attempt=0
# [  1.68s] DONE  RT_0009_decision agent=decision    on=CPU
# [  1.69s] DONE  RT_0009_comms    agent=comms       on=CPU
# [  1.69s] START RT_0010_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.58s req(cpu=1, gpu=0) attempt=0
# [  1.69s] DONE  RT_0009_fusion   agent=fusion      on=CPU
# [  1.69s] START RT_0010_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.59s req(cpu=1, gpu=0) attempt=0
# [  1.79s] DONE  RT_0006_threat   agent=threat      on=GPU
# [  1.79s] DONE  RT_0010_ingest   agent=ingest      on=CPU
# [  1.79s] START RT_0007_threat   agent=threat      kind=threat_detect on=GPU wait= 1.06s req(cpu=2, gpu=1) attempt=0
# [  1.79s] START RT_0010_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.69s req(cpu=1, gpu=0) attempt=0
# [  1.79s] START RT_0010_decision agent=decision    kind=decision     on=CPU wait= 0.69s req(cpu=1, gpu=0) attempt=0
# [  1.81s] DONE  RT_0010_pre      agent=preprocess  on=CPU
# [  1.82s] START RT_0010_comms    agent=comms       kind=comms        on=CPU wait= 0.71s req(cpu=1, gpu=0) attempt=0
# [  1.88s] DONE  RT_0010_decision agent=decision    on=CPU
# [  1.88s] DONE  RT_0010_comms    agent=comms       on=CPU
# [  1.88s] START RT_0011_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.65s req(cpu=1, gpu=0) attempt=0
# [  1.88s] START RT_0011_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.66s req(cpu=1, gpu=0) attempt=0
# [  1.95s] DONE  RT_0010_fusion   agent=fusion      on=CPU
# [  1.95s] START RT_0011_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.72s req(cpu=1, gpu=0) attempt=0
# [  1.98s] DONE  RT_0011_ingest   agent=ingest      on=CPU
# [  2.00s] DONE  RT_0011_pre      agent=preprocess  on=CPU
# [  2.01s] START RT_0011_decision agent=decision    kind=decision     on=CPU wait= 0.78s req(cpu=1, gpu=0) attempt=0
# [  2.01s] HEALTH sub=105 start=62 ok=58 fail=1 retry=1 dlq=0 dlq_items=0
# [  2.05s] DONE  RT_0007_threat   agent=threat      on=GPU
# [  2.05s] START RT_0011_comms    agent=comms       kind=comms        on=CPU wait= 0.82s req(cpu=1, gpu=0) attempt=0
# [  2.05s] START RT_0012_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.70s req(cpu=1, gpu=0) attempt=0
# [  2.09s] DONE  RT_0011_decision agent=decision    on=CPU
# [  2.09s] START RT_0012_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.74s req(cpu=1, gpu=0) attempt=0
# [  2.10s] DONE  RT_0011_fusion   agent=fusion      on=CPU
# [  2.10s] START RT_0012_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.75s req(cpu=1, gpu=0) attempt=0
# [  2.11s] DONE  RT_0011_comms    agent=comms       on=CPU
# [  2.15s] DONE  RT_0012_ingest   agent=ingest      on=CPU
# [  2.15s] START RT_0012_decision agent=decision    kind=decision     on=CPU wait= 0.80s req(cpu=1, gpu=0) attempt=0
# [  2.21s] DONE  RT_0012_pre      agent=preprocess  on=CPU
# [  2.21s] START RT_0012_comms    agent=comms       kind=comms        on=CPU wait= 0.87s req(cpu=1, gpu=0) attempt=0
# [  2.23s] DONE  RT_0012_decision agent=decision    on=CPU
# [  2.23s] START RT_0008_threat   agent=threat      kind=threat_detect on=GPU wait= 1.37s req(cpu=2, gpu=1) attempt=0
# [  2.25s] FAIL  RT_0012_fusion   agent=fusion      err=RuntimeError: simulated transient failure
# [  2.26s] START RT_0013_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.79s req(cpu=1, gpu=0) attempt=0
# [  2.28s] DONE  RT_0012_comms    agent=comms       on=CPU
# [  2.28s] START RT_0013_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.81s req(cpu=1, gpu=0) attempt=0
# [  2.36s] FAIL  RT_0013_ingest   agent=ingest      err=RuntimeError: simulated transient failure
# [  2.36s] START RT_0013_fusion   agent=fusion      kind=fusion       on=CPU wait= 0.89s req(cpu=1, gpu=0) attempt=0
# [  2.40s] DONE  RT_0013_pre      agent=preprocess  on=CPU
# [  2.49s] DONE  RT_0008_threat   agent=threat      on=GPU
# [  2.49s] START RT_0013_decision agent=decision    kind=decision     on=CPU wait= 1.02s req(cpu=1, gpu=0) attempt=0
# [  2.49s] START RT_0013_comms    agent=comms       kind=comms        on=CPU wait= 1.02s req(cpu=1, gpu=0) attempt=0
# [  2.51s] DONE  RT_0013_fusion   agent=fusion      on=CPU
# [  2.51s] START RT_0009_threat   agent=threat      kind=threat_detect on=GPU wait= 1.53s req(cpu=2, gpu=1) attempt=0
# [  2.55s] DONE  RT_0013_comms    agent=comms       on=CPU
# [  2.55s] START RT_0014_ingest   agent=ingest      kind=ingest       on=CPU wait= 0.96s req(cpu=1, gpu=0) attempt=0
# [  2.57s] DONE  RT_0013_decision agent=decision    on=CPU
# [  2.57s] START RT_0014_pre      agent=preprocess  kind=preprocess   on=CPU wait= 0.98s req(cpu=1, gpu=0) attempt=0
# [  2.66s] DONE  RT_0014_ingest   agent=ingest      on=CPU
# [  2.66s] START RT_0014_fusion   agent=fusion      kind=fusion       on=CPU wait= 1.07s req(cpu=1, gpu=0) attempt=0
# [  2.69s] DONE  RT_0014_pre      agent=preprocess  on=CPU
# [  2.77s] DONE  RT_0009_threat   agent=threat      on=GPU
# [  2.77s] START RT_0014_decision agent=decision    kind=decision     on=CPU wait= 1.18s req(cpu=1, gpu=0) attempt=0
# [  2.77s] START RT_0014_comms    agent=comms       kind=comms        on=CPU wait= 1.18s req(cpu=1, gpu=0) attempt=0
# [  2.81s] DONE  RT_0014_fusion   agent=fusion      on=CPU
# [  2.81s] START RT_0015_ingest   agent=ingest      kind=ingest       on=CPU wait= 1.10s req(cpu=1, gpu=0) attempt=0
# [  2.83s] DONE  RT_0014_comms    agent=comms       on=CPU
# [  2.83s] START RT_0015_pre      agent=preprocess  kind=preprocess   on=CPU wait= 1.12s req(cpu=1, gpu=0) attempt=0
# [  2.85s] DONE  RT_0014_decision agent=decision    on=CPU
# [  2.85s] START RT_0015_fusion   agent=fusion      kind=fusion       on=CPU wait= 1.14s req(cpu=1, gpu=0) attempt=0
# [  2.91s] DONE  RT_0015_ingest   agent=ingest      on=CPU
# [  2.95s] FAIL  RT_0015_pre      agent=preprocess  err=RuntimeError: simulated transient failure
# [  2.96s] START RT_0015_decision agent=decision    kind=decision     on=CPU wait= 1.24s req(cpu=1, gpu=0) attempt=0
# [  3.00s] DONE  RT_0015_fusion   agent=fusion      on=CPU
# [  3.01s] START RT_0015_comms    agent=comms       kind=comms        on=CPU wait= 1.29s req(cpu=1, gpu=0) attempt=0
# [  3.01s] HEALTH sub=155 start=85 ok=79 fail=4 retry=4 dlq=0 dlq_items=0
# [  3.04s] DONE  RT_0015_decision agent=decision    on=CPU
# [  3.04s] START RT_0010_threat   agent=threat      kind=threat_detect on=GPU wait= 1.93s req(cpu=2, gpu=1) attempt=0
# [  3.07s] DONE  RT_0015_comms    agent=comms       on=CPU
# [  3.07s] START RT_0016_ingest   agent=ingest      kind=ingest       on=CPU wait= 1.23s req(cpu=1, gpu=0) attempt=0
# [  3.17s] DONE  RT_0016_ingest   agent=ingest      on=CPU
# [  3.17s] START RT_0016_pre      agent=preprocess  kind=preprocess   on=CPU wait= 1.34s req(cpu=1, gpu=0) attempt=0
# [  3.29s] DONE  RT_0010_threat   agent=threat      on=GPU
# [  3.29s] START RT_0016_fusion   agent=fusion      kind=fusion       on=CPU wait= 1.46s req(cpu=1, gpu=0) attempt=0
# [  3.29s] DONE  RT_0016_pre      agent=preprocess  on=CPU
# [  3.30s] START RT_0016_decision agent=decision    kind=decision     on=CPU wait= 1.46s req(cpu=1, gpu=0) attempt=0
# [  3.38s] DONE  RT_0016_decision agent=decision    on=CPU
# [  3.38s] START RT_0016_comms    agent=comms       kind=comms        on=CPU wait= 1.54s req(cpu=1, gpu=0) attempt=0
# [  3.44s] DONE  RT_0016_comms    agent=comms       on=CPU
# [  3.44s] START RT_0017_ingest   agent=ingest      kind=ingest       on=CPU wait= 1.49s req(cpu=1, gpu=0) attempt=0
# [  3.44s] DONE  RT_0016_fusion   agent=fusion      on=CPU
# [  3.44s] START RT_0017_pre      agent=preprocess  kind=preprocess   on=CPU wait= 1.49s req(cpu=1, gpu=0) attempt=0
# [  3.55s] DONE  RT_0017_ingest   agent=ingest      on=CPU
# [  3.55s] START RT_0017_fusion   agent=fusion      kind=fusion       on=CPU wait= 1.59s req(cpu=1, gpu=0) attempt=0
# [  3.57s] DONE  RT_0017_pre      agent=preprocess  on=CPU
# [  3.70s] DONE  RT_0017_fusion   agent=fusion      on=CPU
# [  3.70s] START RT_0017_decision agent=decision    kind=decision     on=CPU wait= 1.74s req(cpu=1, gpu=0) attempt=0
# [  3.78s] DONE  RT_0017_decision agent=decision    on=CPU
# [  3.78s] START RT_0017_comms    agent=comms       kind=comms        on=CPU wait= 1.83s req(cpu=1, gpu=0) attempt=0
# [  3.84s] DONE  RT_0017_comms    agent=comms       on=CPU
# [  3.85s] START RT_0011_threat   agent=threat      kind=threat_detect on=GPU wait= 2.62s req(cpu=2, gpu=1) attempt=0
# [  4.01s] HEALTH sub=206 start=97 ok=92 fail=4 retry=4 dlq=0 dlq_items=0
# [  4.10s] DONE  RT_0011_threat   agent=threat      on=GPU
# [  5.02s] HEALTH sub=260 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  6.02s] HEALTH sub=310 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  4.71s] HEALTH sub=358 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  5.72s] HEALTH sub=408 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  6.72s] HEALTH sub=462 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  7.72s] HEALTH sub=512 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  8.72s] HEALTH sub=560 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [  9.73s] HEALTH sub=610 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 10.73s] HEALTH sub=664 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 11.73s] HEALTH sub=714 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 12.73s] HEALTH sub=762 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 13.74s] HEALTH sub=812 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 14.74s] HEALTH sub=866 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 15.74s] HEALTH sub=916 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 16.75s] HEALTH sub=964 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 17.75s] HEALTH sub=1014 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 18.75s] HEALTH sub=1068 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 19.76s] HEALTH sub=1118 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 20.76s] HEALTH sub=1166 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 21.76s] HEALTH sub=1222 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 22.77s] HEALTH sub=1270 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 23.77s] HEALTH sub=1320 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 24.77s] HEALTH sub=1368 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 25.78s] HEALTH sub=1424 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 26.78s] HEALTH sub=1472 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
# [ 27.78s] HEALTH sub=1516 start=97 ok=93 fail=4 retry=4 dlq=0 dlq_items=0
#
# === FINAL STATS ===
# {'submitted': 1516, 'started': 97, 'succeeded': 93, 'failed': 4, 'retried': 4, 'dlq': 0}
# DLQ items: 0
#
# Log saved to: logs/task3_20260204_230517.log
# {'stats': {'submitted': 1516,
#   'started': 97,
#   'succeeded': 93,
#   'failed': 4,
#   'retried': 4,
#   'dlq': 0},
#  'dlq_count': 0,
#  'log_file': 'logs/task3_20260204_230517.log'}
